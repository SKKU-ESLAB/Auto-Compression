# %%
import matplotlib.pyplot as plt

with open("output.txt", "r") as f:
    lines = f.readlines()

read_clocks = []
read_addrs = []
write_clocks = []
write_addrs = []
first_clk = 0

for line in lines:
    log = line.split()
    if log[2] == '0':
        read_clocks.append(int(log[1]))
        read_addrs.append(int(log[4]))
    elif log[2] == '1':
        write_clocks.append(int(log[1]))
        write_addrs.append(int(log[4]))

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(30, 10))

ax1.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
ax1.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
ax2.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
ax2.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
plt.legend()
ax1.set_ylim(4293000000, 4295000000)
ax2.set_ylim(-10000, 340000)

plt.show()

# %%
import matplotlib.pyplot as plt

with open("out80.txt", "r") as f:
    lines = f.readlines()

read_clocks = []
write_clocks = []
read_addrs = []
write_addrs = []
first_clk = 0

for line in lines:
    log = line.split()
    #print(len(log))
    if len(log) >= 12:
        if log[2] == "Read":
            if (first_clk == 0):
                first_clk = int(log[0][:-1])
            read_clocks.append(int(log[0][:-1]) - first_clk)
            
            #read_addrs.append(int(log[10], 16))
            read_addrs.append(int(log[10], 16)-0x140000000)
        elif log[2] == "Write":
            if (first_clk == 0):
                first_clk = int(log[0][:-1])
            write_clocks.append(int(log[0][:-1]) - first_clk)
            #write_addrs.append(int(log[10], 16))
            write_addrs.append(int(log[10], 16)-0x140000000)

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(30, 10))


ax1.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
ax1.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
ax2.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
ax2.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
plt.legend()
ax1.set_ylim(0xffe00000, 0x100000000)
ax2.set_ylim(-10000, 500000)
plt.show()

# %%
import matplotlib.pyplot as plt

with open("out_noMF.txt", "r") as f:
    lines = f.readlines()

read_clocks = []
write_clocks = []
read_addrs = []
write_addrs = []
first_clk = 0

for line in lines:
    log = line.split()
    #print(len(log))
    if len(log) >= 12:
        if log[2] == "Read":
            if (first_clk == 0):
                first_clk = int(log[0][:-1])
            read_clocks.append(int(log[0][:-1]) - first_clk)
            
            #read_addrs.append(int(log[10], 16))
            read_addrs.append(int(log[10], 16)-0x140000000)
        elif log[2] == "Write":
            if (first_clk == 0):
                first_clk = int(log[0][:-1])
            write_clocks.append(int(log[0][:-1]) - first_clk)
            #write_addrs.append(int(log[10], 16))
            write_addrs.append(int(log[10], 16)-0x140000000)

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(30, 10))

#ax1.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
#ax1.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
ax2.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
ax2.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
plt.legend()
#ax1.set_ylim(0xffe00000, 0x100000000)
#ax2.set_ylim(-10000, 500000)
#ax1.set_ylim(0xffe00000, 0x100000000)
#ax2.set_ylim(-10000, 500000)
#ax2.set_xlim(-3000000, 117000000)
#ax2.set_ylim(258000, 323000)
plt.show()

# %%
import matplotlib.pyplot as plt

with open("out_noMF.txt", "r") as f:
    lines = f.readlines()

read_clocks = []
write_clocks = []
read_addrs = []
write_addrs = []

for line in lines:
    log = line.split()
    if len(log) >= 13:
        if log[2] == "Read":
            read_clocks.append(int(log[0][:-1]))
            read_addrs.append(int(log[10], 16)-0x140000000)
        elif log[2] == "Write":
            write_clocks.append(int(log[0][:-1]))
            write_addrs.append(int(log[10], 16)-0x140000000)

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(20, 10))

ax1.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
ax1.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
ax2.plot(read_clocks, read_addrs, marker='+', markersize=2, linestyle="None", label="read")
ax2.plot(write_clocks, write_addrs, marker='+', markersize=2, linestyle="None", label="write")
plt.legend()
ax1.set_ylim(0xffe00000, 0x100000000)
ax2.set_ylim(-10000, 500000)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-5e4e1d859025> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 with open("out_noMF.txt", "r") as f:
#       4     lines = f.readlines()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'out_noMF.txt'
